# %%
import numpy as np
import matplotlib.pyplot as plt
import mkl

mkl.set_num_threads(4)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

# %% [markdown]
# # MNIST dataset

# %%
import mnist
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)

# %% [markdown]
# # Restricted Boltzmann Machine & Contrastive Divergence algorithm

# %%
def sigmoid(matrix):
    return 1.0 / (1.0 + np.exp(-matrix))

class Rbm:
    def __init__(self, visible_size, hidden_size, learning_rate, momentum):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size+1)).astype(np.float32)
        self.W[:, -1] = 0.0
        self.W[-1, :] = 0.0
        self.M = zeros(self.visible_size+1, self.hidden_size+1)

# %%
def reconstuction_error(rbm, minibatch):
    observations_count = minibatch.shape[0]
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    hidden[:, :-1] = sigmoid(minibatch @ rbm.W[:, :-1]) > rand(hidden.shape[0], hidden.shape[1] - 1)
    visible = sigmoid(hidden @ rbm.W[:-1, :].T)

    error = np.sum((minibatch[:, :-1] - visible) ** 2) / observations_count

    return error

# %%
def train_epoch(rbm, dataset, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(rbm, batch)
        if batch_idx % round(batches_limit / 50) == 0: print("#", end="")

def run_training(rbm, dataset, monitoring_set, batch_size, epochs_count):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch),  end="\t")
        
        if epoch == 5:
            rbm.momentum = 0.8

        start_time = time.time()
        train_epoch(rbm, dataset, batch_size)
        elapsed = time.time() - start_time
        
        error = reconstuction_error(rbm, monitoring_set)
        print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

    print("Training finished!")

# %%
def draw_filters(rbm):
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# # 1. RBM Training with momentum

# %%
def cdk(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]

    # POSITIVE PHASE
    positive_visible = minibatch
    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    positive_hidden[:, :-1] = sigmoid(positive_visible @ rbm.W[:, :-1])
    positive_phase_gradient = (positive_visible.T @ positive_hidden) / observations_count

    # NEGATIVE PHASE
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    # sample hidden layer, get h_0 using input data
    negative_hidden[:, :-1] = positive_hidden[:, :-1] > rand(observations_count, rbm.hidden_size)

    # sample visible layer, get v_1
    negative_visible[:, :-1] = sigmoid(negative_hidden @ rbm.W[:-1, :].T) > rand(observations_count, rbm.visible_size)

    for _ in range(k - 1):
        # sample hidden layer, get h_{k - 1}, using v_{k - 1}
        negative_hidden[:, :-1] = sigmoid(negative_visible @ rbm.W[:, :-1]) > rand(observations_count, rbm.hidden_size)

        # sample hidden layer, get v_k, using h_{k - 1}
        negative_visible[:, :-1] = sigmoid(negative_hidden @ rbm.W[:-1, :].T) > rand(observations_count, rbm.visible_size)

    # NEGATIVE GRADIENT
    negative_hidden[:, :-1] = sigmoid(negative_visible @ rbm.W[:, :-1])
    negative_phase_gradient = (negative_visible.T @ negative_hidden) / observations_count

    rbm.M = rbm.momentum * rbm.M + rbm.learning_rate * (positive_phase_gradient - negative_phase_gradient)
    rbm.W = rbm.W + rbm.M

# %%
import time

DATASET_SIZE = 20000 # 60000 for whole dataset
DIGIT_SIZE = 28

VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 128

mnist_train = mnist.train_images().astype(np.float32) / 255.0
np.random.shuffle(mnist_train)
dataset = np.reshape(mnist_train[:DATASET_SIZE], newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
dataset = append_ones(dataset)

monitoring_indeces = np.random.choice(DATASET_SIZE, 256, replace=False)
monitoring_set = dataset[monitoring_indeces]

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

LEARNING_RATE = 0.1
MOMENTUM = 0.5

rbm = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM)
draw_filters(rbm)

run_training(rbm, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT)

draw_filters(rbm)
# Out:
# Epoch 0:	#####################################################	elapsed: 0.50s, reconstruction error: 26.46
# Epoch 1:	#####################################################	elapsed: 0.46s, reconstruction error: 21.29
# Epoch 2:	#####################################################	elapsed: 0.47s, reconstruction error: 18.68
# Epoch 3:	#####################################################	elapsed: 0.47s, reconstruction error: 17.28
# Epoch 4:	#####################################################	elapsed: 0.44s, reconstruction error: 16.45
# Epoch 5:	#####################################################	elapsed: 0.41s, reconstruction error: 15.11
# Epoch 6:	#####################################################	elapsed: 0.41s, reconstruction error: 14.44
# Epoch 7:	#####################################################	elapsed: 0.41s, reconstruction error: 13.76
# Epoch 8:	#####################################################	elapsed: 0.41s, reconstruction error: 12.96
# Epoch 9:	#####################################################	elapsed: 0.40s, reconstruction error: 12.92
# Epoch 10:	#####################################################	elapsed: 0.41s, reconstruction error: 12.45
# Epoch 11:	#####################################################	elapsed: 0.41s, reconstruction error: 12.14
# Epoch 12:	#####################################################	elapsed: 0.39s, reconstruction error: 11.88
# Epoch 13:	#####################################################	elapsed: 0.40s, reconstruction error: 11.84
# Epoch 14:	#####################################################	elapsed: 0.41s, reconstruction error: 11.59
# Epoch 15:	#####################################################	elapsed: 0.41s, reconstruction error: 11.56
# Epoch 16:	#####################################################	elapsed: 0.40s, reconstruction error: 11.51
# Epoch 17:	#####################################################	elapsed: 0.41s, reconstruction error: 11.40
# Epoch 18:	#####################################################	elapsed: 0.42s, reconstruction error: 11.38
# Epoch 19:	#####################################################	elapsed: 0.41s, reconstruction error: 11.19
# Epoch 20:	#####################################################	elapsed: 0.41s, reconstruction error: 11.17
# Epoch 21:	#####################################################	elapsed: 0.42s, reconstruction error: 11.13
# Epoch 22:	#####################################################	elapsed: 0.43s, reconstruction error: 11.17
# Epoch 23:	#####################################################	elapsed: 0.41s, reconstruction error: 10.88
# Epoch 24:	#####################################################	elapsed: 0.42s, reconstruction error: 11.05
# Epoch 25:	#####################################################	elapsed: 0.41s, reconstruction error: 10.88
# Epoch 26:	#####################################################	elapsed: 0.40s, reconstruction error: 10.82
# Epoch 27:	#####################################################	elapsed: 0.41s, reconstruction error: 10.66
# Epoch 28:	#####################################################	elapsed: 0.44s, reconstruction error: 10.75
# Epoch 29:	#####################################################	elapsed: 0.40s, reconstruction error: 10.78
# Epoch 30:	#####################################################	elapsed: 0.47s, reconstruction error: 10.63
# Epoch 31:	#####################################################	elapsed: 0.40s, reconstruction error: 10.65
# Epoch 32:	#####################################################	elapsed: 0.43s, reconstruction error: 10.55
# Epoch 33:	#####################################################	elapsed: 0.40s, reconstruction error: 10.50
# Epoch 34:	#####################################################	elapsed: 0.45s, reconstruction error: 10.64
# Epoch 35:	#####################################################	elapsed: 0.47s, reconstruction error: 10.55
# Epoch 36:	#####################################################	elapsed: 0.45s, reconstruction error: 10.50
# Epoch 37:	#####################################################	elapsed: 0.45s, reconstruction error: 10.38
# Epoch 38:	#####################################################	elapsed: 0.47s, reconstruction error: 10.51
# Epoch 39:	#####################################################	elapsed: 0.45s, reconstruction error: 10.54
# Epoch 40:	#####################################################	elapsed: 0.48s, reconstruction error: 10.37
# Epoch 41:	#####################################################	elapsed: 0.48s, reconstruction error: 10.40
# Epoch 42:	#####################################################	elapsed: 0.44s, reconstruction error: 10.47
# Epoch 43:	#####################################################	elapsed: 0.46s, reconstruction error: 10.46
# Epoch 44:	#####################################################	elapsed: 0.45s, reconstruction error: 10.36
# Epoch 45:	#####################################################	elapsed: 0.48s, reconstruction error: 10.37
# Epoch 46:	#####################################################	elapsed: 0.46s, reconstruction error: 10.20
# Epoch 47:	#####################################################	elapsed: 0.46s, reconstruction error: 10.29
# Epoch 48:	#####################################################	elapsed: 0.52s, reconstruction error: 10.13
# Epoch 49:	#####################################################	elapsed: 0.54s, reconstruction error: 10.29
# Training finished!

# %% [markdown]
# # 2. DBN Training

# %%
def propagate_up(dbn, layers_count, visible):
    for i in range(layers_count):
        visible = append_ones(sigmoid(visible @ dbn[i].W[:, :-1]))
    return visible

def propagate_down(dbn, layers_count, hidden):
    for i in reversed(range(layers_count)):
        hidden = append_ones(sigmoid(hidden @ np.transpose(dbn[i].W[:-1, :])))
    return hidden

# %% [markdown]
# ### DBN reconstruction error

# %%
def dbn_reconstuction_error(dbn, layers_count, minibatch):
    propagated = propagate_up(dbn, layers_count, minibatch)
    return reconstuction_error(dbn[layers_count], propagated)

# %% [markdown]
# ### Sampling in Deep Belief Networks

# %%
def sample_rbm(rbm, minibatch, steps):
    observations_count = minibatch.shape[0]

    visible = minibatch
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    for cd_i in range(steps):
        hidden[:, :-1] = sigmoid(visible @ rbm.W[:, :-1])
        hidden[:, :-1] = (hidden[:, :-1] > rand(observations_count, rbm.hidden_size)).astype(np.float32)
    
        visible[:, :-1] = sigmoid(hidden @ np.transpose(rbm.W[:-1, :]))
        if cd_i < (steps - 1):
            visible[:, :-1] = (visible[:, :-1] > rand(observations_count, rbm.visible_size)).astype(np.float32)

    return visible

# %%
def sample_dbn(dbn, layer_idx, minibatch, steps):
    sample_visible = propagate_up(dbn, layer_idx, minibatch)
    sample_hidden = sample_rbm(dbn[layer_idx], sample_visible, steps)
    sample = propagate_down(dbn, layer_idx, sample_hidden)

    return sample

# %%
def draw_layer_samples(dbn, layer_idx, minibatch, steps=200):
    samples = sample_dbn(dbn, layer_idx, minibatch, steps)
    tiles(np.reshape(samples[:, :-1], newshape=(-1, 16, 28, 28)))

# %% [markdown]
# ### Greedy layer-wise training

# %%
def train_dbn(dbn, layer_idx, dataset, batch_size):
    dataset = propagate_up(dbn, layer_idx, dataset)

    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(dbn[layer_idx], batch)
        if batch_idx % round(batches_limit / 50) == 0: print("#", end="")

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

LEARNING_RATE = 0.1
MOMENTUM = 0.5

DBN_HIDDEN_LAYER_SIZE = 200
dbn = [
    Rbm(VISIBLE_LAYER_SIZE, DBN_HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM),
    Rbm(DBN_HIDDEN_LAYER_SIZE, DBN_HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM),
    Rbm(DBN_HIDDEN_LAYER_SIZE, DBN_HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM)
]

for layer_idx in range(len(dbn)):
    print("\nLearning layer {}".format(layer_idx))

    for epoch in range(EPOCHS_COUNT):
        print("Epoch {}:".format(epoch),  end="\t")

        if epoch == 5:
            dbn[layer_idx].momentum = 0.8
        
        start_time = time.time()
        train_dbn(dbn, layer_idx, dataset, BATCH_SIZE)
        elapsed = time.time() - start_time
        
        error = dbn_reconstuction_error(dbn, layer_idx, monitoring_set)
        print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))
    
print("Training finished!")
# Out:
# Learning layer 0
# Epoch 0:	#####################################################	elapsed: 0.58s, reconstruction error: 25.06
# Epoch 1:	#####################################################	elapsed: 0.57s, reconstruction error: 19.46
# Epoch 2:	#####################################################	elapsed: 0.48s, reconstruction error: 16.68
# Epoch 3:	#####################################################	elapsed: 0.54s, reconstruction error: 15.34
# Epoch 4:	#####################################################	elapsed: 0.51s, reconstruction error: 14.59
# Epoch 5:	#####################################################	elapsed: 0.57s, reconstruction error: 13.24
# Epoch 6:	#####################################################	elapsed: 0.52s, reconstruction error: 12.52
# Epoch 7:	#####################################################	elapsed: 0.49s, reconstruction error: 11.86
# Epoch 8:	#####################################################	elapsed: 0.49s, reconstruction error: 11.39
# Epoch 9:	#####################################################	elapsed: 0.54s, reconstruction error: 10.83
# Epoch 10:	#####################################################	elapsed: 0.50s, reconstruction error: 10.59
# Epoch 11:	#####################################################	elapsed: 0.49s, reconstruction error: 10.39
# Epoch 12:	#####################################################	elapsed: 0.49s, reconstruction error: 10.37
# Epoch 13:	#####################################################	elapsed: 0.50s, reconstruction error: 10.25
# Epoch 14:	#####################################################	elapsed: 0.50s, reconstruction error: 9.85
# Epoch 15:	#####################################################	elapsed: 0.51s, reconstruction error: 9.84
# Epoch 16:	#####################################################	elapsed: 0.55s, reconstruction error: 9.72
# Epoch 17:	#####################################################	elapsed: 0.50s, reconstruction error: 9.45
# Epoch 18:	#####################################################	elapsed: 0.49s, reconstruction error: 9.69
# Epoch 19:	#####################################################	elapsed: 0.50s, reconstruction error: 9.47
# Epoch 20:	#####################################################	elapsed: 0.53s, reconstruction error: 9.45
# Epoch 21:	#####################################################	elapsed: 0.48s, reconstruction error: 9.36
# Epoch 22:	#####################################################	elapsed: 0.48s, reconstruction error: 9.23
# Epoch 23:	#####################################################	elapsed: 0.52s, reconstruction error: 9.36
# Epoch 24:	#####################################################	elapsed: 0.56s, reconstruction error: 9.14
# Epoch 25:	#####################################################	elapsed: 0.55s, reconstruction error: 9.13
# Epoch 26:	#####################################################	elapsed: 0.50s, reconstruction error: 9.16
# Epoch 27:	#####################################################	elapsed: 0.49s, reconstruction error: 9.11
# Epoch 28:	#####################################################	elapsed: 0.50s, reconstruction error: 9.06
# Epoch 29:	#####################################################	elapsed: 0.55s, reconstruction error: 9.02
# Epoch 30:	#####################################################	elapsed: 0.50s, reconstruction error: 8.91
# Epoch 31:	#####################################################	elapsed: 0.48s, reconstruction error: 8.85
# Epoch 32:	#####################################################	elapsed: 0.51s, reconstruction error: 8.85
# Epoch 33:	#####################################################	elapsed: 0.51s, reconstruction error: 8.84
# Epoch 34:	#####################################################	elapsed: 0.50s, reconstruction error: 8.85
# Epoch 35:	#####################################################	elapsed: 0.51s, reconstruction error: 8.77
# Epoch 36:	#####################################################	elapsed: 0.46s, reconstruction error: 8.76
# Epoch 37:	#####################################################	elapsed: 0.47s, reconstruction error: 8.73
# Epoch 38:	#####################################################	elapsed: 0.50s, reconstruction error: 8.76
# Epoch 39:	#####################################################	elapsed: 0.46s, reconstruction error: 8.79
# Epoch 40:	#####################################################	elapsed: 0.46s, reconstruction error: 8.68
# Epoch 41:	#####################################################	elapsed: 0.57s, reconstruction error: 8.75
# Epoch 42:	#####################################################	elapsed: 0.57s, reconstruction error: 8.75
# Epoch 43:	#####################################################	elapsed: 0.52s, reconstruction error: 8.72
# Epoch 44:	#####################################################	elapsed: 0.52s, reconstruction error: 8.63
# Epoch 45:	#####################################################	elapsed: 0.55s, reconstruction error: 8.64
# Epoch 46:	#####################################################	elapsed: 0.53s, reconstruction error: 8.78
# Epoch 47:	#####################################################	elapsed: 0.51s, reconstruction error: 8.62
# Epoch 48:	#####################################################	elapsed: 0.55s, reconstruction error: 8.65
# Epoch 49:	#####################################################	elapsed: 0.53s, reconstruction error: 8.78
#
# Learning layer 1
# Epoch 0:	#####################################################	elapsed: 0.25s, reconstruction error: 14.50
# Epoch 1:	#####################################################	elapsed: 0.23s, reconstruction error: 10.86
# Epoch 2:	#####################################################	elapsed: 0.28s, reconstruction error: 9.18
# Epoch 3:	#####################################################	elapsed: 0.23s, reconstruction error: 8.22
# Epoch 4:	#####################################################	elapsed: 0.27s, reconstruction error: 7.52
# Epoch 5:	#####################################################	elapsed: 0.23s, reconstruction error: 6.93
# Epoch 6:	#####################################################	elapsed: 0.23s, reconstruction error: 6.23
# Epoch 7:	#####################################################	elapsed: 0.25s, reconstruction error: 5.92
# Epoch 8:	#####################################################	elapsed: 0.24s, reconstruction error: 5.65
# Epoch 9:	#####################################################	elapsed: 0.25s, reconstruction error: 5.50
# Epoch 10:	#####################################################	elapsed: 0.26s, reconstruction error: 5.21
# Epoch 11:	#####################################################	elapsed: 0.22s, reconstruction error: 5.20
# Epoch 12:	#####################################################	elapsed: 0.27s, reconstruction error: 4.92
# Epoch 13:	#####################################################	elapsed: 0.22s, reconstruction error: 4.91
# Epoch 14:	#####################################################	elapsed: 0.27s, reconstruction error: 4.83
# Epoch 15:	#####################################################	elapsed: 0.24s, reconstruction error: 4.82
# Epoch 16:	#####################################################	elapsed: 0.26s, reconstruction error: 4.67
# Epoch 17:	#####################################################	elapsed: 0.24s, reconstruction error: 4.68
# Epoch 18:	#####################################################	elapsed: 0.23s, reconstruction error: 4.62
# Epoch 19:	#####################################################	elapsed: 0.23s, reconstruction error: 4.57
# Epoch 20:	#####################################################	elapsed: 0.23s, reconstruction error: 4.46
# Epoch 21:	#####################################################	elapsed: 0.22s, reconstruction error: 4.42
# Epoch 22:	#####################################################	elapsed: 0.23s, reconstruction error: 4.43
# Epoch 23:	#####################################################	elapsed: 0.26s, reconstruction error: 4.38
# Epoch 24:	#####################################################	elapsed: 0.33s, reconstruction error: 4.33
# Epoch 25:	#####################################################	elapsed: 0.25s, reconstruction error: 4.42
# Epoch 26:	#####################################################	elapsed: 0.27s, reconstruction error: 4.40
# Epoch 27:	#####################################################	elapsed: 0.26s, reconstruction error: 4.44
# Epoch 28:	#####################################################	elapsed: 0.26s, reconstruction error: 4.33
# Epoch 29:	#####################################################	elapsed: 0.27s, reconstruction error: 4.30
# Epoch 30:	#####################################################	elapsed: 0.25s, reconstruction error: 4.23
# Epoch 31:	#####################################################	elapsed: 0.25s, reconstruction error: 4.21
# Epoch 32:	#####################################################	elapsed: 0.27s, reconstruction error: 4.32
# Epoch 33:	#####################################################	elapsed: 0.25s, reconstruction error: 4.26
# Epoch 34:	#####################################################	elapsed: 0.26s, reconstruction error: 4.23
# Epoch 35:	#####################################################	elapsed: 0.29s, reconstruction error: 4.28
# Epoch 36:	#####################################################	elapsed: 0.26s, reconstruction error: 4.22
# Epoch 37:	#####################################################	elapsed: 0.26s, reconstruction error: 4.29
# Epoch 38:	#####################################################	elapsed: 0.26s, reconstruction error: 4.25
# Epoch 39:	#####################################################	elapsed: 0.26s, reconstruction error: 4.18
# Epoch 40:	#####################################################	elapsed: 0.23s, reconstruction error: 4.08
# Epoch 41:	#####################################################	elapsed: 0.24s, reconstruction error: 4.16
# Epoch 42:	#####################################################	elapsed: 0.28s, reconstruction error: 4.24
# Epoch 43:	#####################################################	elapsed: 0.29s, reconstruction error: 4.14
# Epoch 44:	#####################################################	elapsed: 0.22s, reconstruction error: 4.05
# Epoch 45:	#####################################################	elapsed: 0.26s, reconstruction error: 4.03
# Epoch 46:	#####################################################	elapsed: 0.24s, reconstruction error: 4.15
# Epoch 47:	#####################################################	elapsed: 0.28s, reconstruction error: 4.23
# Epoch 48:	#####################################################	elapsed: 0.24s, reconstruction error: 4.07
# Epoch 49:	#####################################################	elapsed: 0.28s, reconstruction error: 4.02
#
# Learning layer 2
# Epoch 0:	#####################################################	elapsed: 0.32s, reconstruction error: 10.46
# Epoch 1:	#####################################################	elapsed: 0.30s, reconstruction error: 7.70
# Epoch 2:	#####################################################	elapsed: 0.30s, reconstruction error: 6.30
# Epoch 3:	#####################################################	elapsed: 0.28s, reconstruction error: 5.55
# Epoch 4:	#####################################################	elapsed: 0.29s, reconstruction error: 5.20
# Epoch 5:	#####################################################	elapsed: 0.30s, reconstruction error: 4.63
# Epoch 6:	#####################################################	elapsed: 0.29s, reconstruction error: 4.17
# Epoch 7:	#####################################################	elapsed: 0.29s, reconstruction error: 3.94
# Epoch 8:	#####################################################	elapsed: 0.29s, reconstruction error: 3.79
# Epoch 9:	#####################################################	elapsed: 0.29s, reconstruction error: 3.75
# Epoch 10:	#####################################################	elapsed: 0.29s, reconstruction error: 3.66
# Epoch 11:	#####################################################	elapsed: 0.28s, reconstruction error: 3.56
# Epoch 12:	#####################################################	elapsed: 0.28s, reconstruction error: 3.42
# Epoch 13:	#####################################################	elapsed: 0.30s, reconstruction error: 3.45
# Epoch 14:	#####################################################	elapsed: 0.34s, reconstruction error: 3.36
# Epoch 15:	#####################################################	elapsed: 0.28s, reconstruction error: 3.30
# Epoch 16:	#####################################################	elapsed: 0.30s, reconstruction error: 3.22
# Epoch 17:	#####################################################	elapsed: 0.29s, reconstruction error: 3.33
# Epoch 18:	#####################################################	elapsed: 0.29s, reconstruction error: 3.22
# Epoch 19:	#####################################################	elapsed: 0.28s, reconstruction error: 3.14
# Epoch 20:	#####################################################	elapsed: 0.26s, reconstruction error: 3.25
# Epoch 21:	#####################################################	elapsed: 0.27s, reconstruction error: 3.01
# Epoch 22:	#####################################################	elapsed: 0.26s, reconstruction error: 3.10
# Epoch 23:	#####################################################	elapsed: 0.27s, reconstruction error: 3.12
# Epoch 24:	#####################################################	elapsed: 0.29s, reconstruction error: 3.08
# Epoch 25:	#####################################################	elapsed: 0.28s, reconstruction error: 3.07
# Epoch 26:	#####################################################	elapsed: 0.28s, reconstruction error: 2.99
# Epoch 27:	#####################################################	elapsed: 0.27s, reconstruction error: 3.04
# Epoch 28:	#####################################################	elapsed: 0.27s, reconstruction error: 2.99
# Epoch 29:	#####################################################	elapsed: 0.27s, reconstruction error: 3.05
# Epoch 30:	#####################################################	elapsed: 0.27s, reconstruction error: 2.93
# Epoch 31:	#####################################################	elapsed: 0.24s, reconstruction error: 2.90
# Epoch 32:	#####################################################	elapsed: 0.26s, reconstruction error: 2.89
# Epoch 33:	#####################################################	elapsed: 0.27s, reconstruction error: 3.00
# Epoch 34:	#####################################################	elapsed: 0.27s, reconstruction error: 2.96
# Epoch 35:	#####################################################	elapsed: 0.31s, reconstruction error: 2.95
# Epoch 36:	#####################################################	elapsed: 0.31s, reconstruction error: 3.01
# Epoch 37:	#####################################################	elapsed: 0.26s, reconstruction error: 2.99
# Epoch 38:	#####################################################	elapsed: 0.34s, reconstruction error: 3.02
# Epoch 39:	#####################################################	elapsed: 0.28s, reconstruction error: 2.96
# Epoch 40:	#####################################################	elapsed: 0.26s, reconstruction error: 2.88
# Epoch 41:	#####################################################	elapsed: 0.31s, reconstruction error: 3.00
# Epoch 42:	#####################################################	elapsed: 0.31s, reconstruction error: 2.93
# Epoch 43:	#####################################################	elapsed: 0.29s, reconstruction error: 2.88
# Epoch 44:	#####################################################	elapsed: 0.27s, reconstruction error: 2.98
# Epoch 45:	#####################################################	elapsed: 0.26s, reconstruction error: 2.87
# Epoch 46:	#####################################################	elapsed: 0.30s, reconstruction error: 2.87
# Epoch 47:	#####################################################	elapsed: 0.25s, reconstruction error: 3.00
# Epoch 48:	#####################################################	elapsed: 0.30s, reconstruction error: 2.87
# Epoch 49:	#####################################################	elapsed: 0.28s, reconstruction error: 2.78
# Training finished!

# %%
draw_layer_samples(dbn, 0, monitoring_set[:8*16])

# %%
draw_layer_samples(dbn, 1, monitoring_set[:8*16])

# %%
draw_layer_samples(dbn, 2, monitoring_set[:8*16])
